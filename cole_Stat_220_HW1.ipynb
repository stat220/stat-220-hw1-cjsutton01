# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW1.ipynb)

# %% [markdown]
# **Problem 1**. Give an example of a variable that is (a) categorical; (b) quantitative; (c) discrete; (d) continuous.

# %% [markdown]
# a) Gender - Male/Female
# b) Age
# c) Dice Roll result
# d) Temperature

# %% [markdown]
# **Problem 2**. Analyze the Carbon_West data file using the following code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
carbon_west = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Carbon_West.dat")
carbon_west
# Out:
#          Nation   CO2
# 0       Albania   2.0
# 1     Australia  15.4
# 2       Austria   6.9
# 3       Belgium   8.3
# 4        Bosnia   6.2
# 5      Bulgaria   5.9
# 6        Canada  15.1
# 7       Croatia   4.0
# 8        Cyprus   5.3
# 9         Czech   9.2
# 10      Denmark   5.9
# 11      Finland   8.7
# 12       France   4.6
# 13      Germany   8.9
# 14       Greece   6.2
# 15      Hungary   4.3
# 16      Ireland   7.3
# 17        Italy   5.3
# 18       Latvia   3.5
# 19    Lithuania   4.4
# 20        Malta   5.4
# 21   Montenegro   3.6
# 22  Netherlands   9.9
# 23   NewZealand   7.7
# 24       Norway   9.3
# 25     Portugal   4.3
# 26      Romania   3.5
# 27       Serbia   5.3
# 28       Slovak   5.7
# 29     Slovenia   6.2
# 30        Spain   5.0
# 31       Sweden   4.5
# 32  Switzerland   4.3
# 33           UK   6.5
# 34           US  16.5

# %%
# from matplotlib import pyplot as plt
# carbon_west['CO2'].plot(kind='hist', bins=20, title='CO2')
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Part a. Construct a histogram of CO2 emissions.

# %%
plt.figure(figsize=(10, 6))
plt.bar(carbon_west['Nation'], carbon_west['CO2'], edgecolor='black')
plt.title('CO2 Emissions by Country')
plt.xlabel('Country')
plt.ylabel('CO2')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Part b. Find the mean, median, and standard deviation.

# %%
mean_value = np.mean(carbon_west["CO2"])
median_value = np.median(carbon_west["CO2"])
std_deviation = np.std(carbon_west["CO2"])

# Display the results
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Standard Deviation: {std_deviation}")
# Out:
# Mean: 6.717142857142858
# Median: 5.9
# Standard Deviation: 3.3086454469884727

# %% [markdown]
# **Problem 3**. Read in the murder data set using the following code. The variable murder is the murder rate (per 100,000 population) for each state in the U.S. in 2017 according to the FBI Uniform Crime Reports. At first, do not use the observation for D.C. (DC).

# %%
murders = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Murder.dat")
murders.drop(murders.index[50], inplace=True)
murders
# Out:
#    state  murder
# 0     AK     8.4
# 1     AL     8.3
# 2     AR     8.6
# 3     AZ     5.9
# 4     CA     4.6
# 5     CO     3.9
# 6     CT     2.8
# 7     DE     5.6
# 8     FL     5.0
# 9     GA     6.7
# 10    HI     2.7
# 11    ID     1.9
# 12    IL     7.8
# 13    IN     6.0
# 14    IO     3.3
# 15    KS     5.5
# 16    KY     5.9
# 17    LA    12.4
# 18    MA     2.5
# 19    MD     9.0
# 20    ME     1.7
# 21    MI     5.7
# 22    MN     2.0
# 23    MO     9.8
# 24    MS     8.2
# 25    MT     3.9
# 26    NC     5.8
# 27    ND     1.3
# 28    NE     2.2
# 29    NH     1.0
# 30    NJ     3.6
# 31    NM     7.1
# 32    NV     2.3
# 33    NY     2.8
# 34    OH     6.1
# 35    OK     6.2
# 36    OR     2.5
# 37    PA     5.8
# 38    RI     1.9
# 39    SC     7.8
# 40    SD     2.9
# 41    TN     7.8
# 42    TX     5.0
# 43    UT     2.4
# 44    VA     5.3
# 45    VT     2.2
# 46    WA     3.1
# 47    WI     3.2
# 48    WV     4.7
# 49    WY     2.6

# %% [markdown]
# Part a. Find the mean and standard deviation for murders without D.C.

# %%
mean_value = np.mean(murders["murder"])
std_deviation = np.std(murders["murder"])

# Display the results
print(f"Mean: {mean_value}")
print(f"Standard Deviation: {std_deviation}")
# Out:
# Mean: 4.874
# Standard Deviation: 2.560297638947472

# %% [markdown]
# Part b. Find the five-number  summary without D.C.

# %%
# Calculate the five-number summary
minimum = np.min(murders["murder"])
q1 = np.percentile(murders["murder"], 25)
median = np.median(murders["murder"])
q3 = np.percentile(murders["murder"], 75)
maximum = np.max(murders["murder"])

# Display the five-number summary
print(f"Minimum: {minimum}")
print(f"1st Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"3rd Quartile (Q3): {q3}")
print(f"Maximum: {maximum}")
# Out:
# Minimum: 1.0
# 1st Quartile (Q1): 2.625
# Median (Q2): 4.85
# 3rd Quartile (Q3): 6.175
# Maximum: 12.4

# %% [markdown]
# Part c. Now include the observation for D.C. and recalculate the mean, median, and five-number summary. What is affected more by this outlier: The mean or the median? The range or the inter-quartile range?

# %%
murders_all = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Murder.dat")
murders_all

mean_value = np.mean(murders["murder"])
median_value = np.median(murders["murder"])
std_deviation = np.std(murders["murder"])

# Display the results
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Standard Deviation: {std_deviation}")

mean_value = np.mean(murders_all["murder"])
median_value = np.median(murders_all["murder"])
std_deviation = np.std(murders_all["murder"])

# Display the results
print(f"Mean with all: {mean_value}")
print(f"Median with all: {median_value}")
print(f"Standard Deviation with all: {std_deviation}")
# Out:
# Mean: 4.874
# Median: 4.85
# Standard Deviation: 2.560297638947472
# Mean with all: 5.252941176470588
# Median with all: 5.0
# Standard Deviation with all: 3.688687153732127

# %%
# Calculate the five-number summary
minimum = np.min(murders["murder"])
q1 = np.percentile(murders["murder"], 25)
median = np.median(murders["murder"])
q3 = np.percentile(murders["murder"], 75)
maximum = np.max(murders["murder"])

# Display the five-number summary
print(f"Minimum: {minimum}")
print(f"1st Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"3rd Quartile (Q3): {q3}")
print(f"Maximum: {maximum}")

# Calculate the five-number summary
minimum = np.min(murders_all["murder"])
q1 = np.percentile(murders_all["murder"], 25)
median = np.median(murders_all["murder"])
q3 = np.percentile(murders_all["murder"], 75)
maximum = np.max(murders_all["murder"])

# Display the five-number summary
print("\n")
print("DATA WITH DC:")
print(f"Minimum: {minimum}")
print(f"1st Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"3rd Quartile (Q3): {q3}")
print(f"Maximum: {maximum}")
# Out:
# Minimum: 1.0
# 1st Quartile (Q1): 2.625
# Median (Q2): 4.85
# 3rd Quartile (Q3): 6.175
# Maximum: 12.4
#
#
# DATA WITH DC:
# Minimum: 1.0
# 1st Quartile (Q1): 2.6500000000000004
# Median (Q2): 5.0
# 3rd Quartile (Q3): 6.45
# Maximum: 24.2

# %% [markdown]
# The mean is more impacted by the inclusion of DC than median is.
# The range is much more impacted by the inclusion of DC than the IQR is.

# %% [markdown]
# **Problem 4**. Read in the Houses data file using the following code.  The variables include price (thousands of dollars), size (square feet), tax bill (dollars), number of bathrooms, number of bedrooms, and whether the house is new (1 = yes, 0 = no) for 100 home sales in Gainesville, Florida. Let
# y = selling price and x = size of home.

# %%
houses = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Houses.dat")
houses
# Out:
#     case   price  size  new  taxes  bedrooms  baths
# 0      1  419.85  2048    0   3104         4      2
# 1      2  219.75   912    0   1173         2      1
# 2      3  356.55  1654    0   3076         4      2
# 3      4  300.00  2068    0   1608         3      2
# 4      5  239.85  1477    0   1454         3      3
# ..   ...     ...   ...  ...    ...       ...    ...
# 95    96  264.00  1060    0    990         2      2
# 96    97  294.75  1730    0   3030         3      2
# 97    98  198.30  1370    0   1580         3      2
# 98    99  132.60  1560    0   1770         3      2
# 99    10  190.80  1340    0   1430         3      2
#
# [100 rows x 7 columns]

# %% [markdown]
# Part a. Construct a scatterplot between square feet and price of a home.

# %%
# Create a scatter plot between "entry" and "time"
plt.figure(figsize=(6, 4))
plt.scatter(houses['size'], houses['price'], alpha=0.7)
plt.title('Scatter Plot: SQ FT vs. Price')
plt.xlabel('Size')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# Part b. Find the correlation between the two variables.

# %%
# Calculate the correlation between "entry" and "time"
correlation = houses['size'].corr(houses['price'])

print(f'Correlation between size and price: {correlation}')
# Out:
# Correlation between size and price: 0.8337847885586537

# %% [markdown]
# Part c. Find and plot the regression line on top of the scatterplot.

# %%
x = houses[['size']]
y = houses['price']

# Create a LinearRegression model
model = LinearRegression()

# Fit the model to the data
model.fit(x, y)

# Retrieve the coefficient (slope) and intercept of the linear regression
slope = model.coef_[0]
intercept = model.intercept_

# Print the regression results
print(f'Slope (Coefficient): {slope}')
print(f'Intercept: {intercept}')
# Out:
# Slope (Coefficient): 0.18989116794379637
# Intercept: -76.3893821074686

# %%
# Plot the scatterplot
plt.figure(figsize=(6, 4))
plt.scatter(x, y, alpha=0.7, label='Scatterplot')

# Plot the regression line
plt.plot(x, model.predict(x), color='red', label='Regression Line')

plt.title('Scatter Plot with Regression Line')
plt.xlabel('size')
plt.ylabel('price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Part d. Create a side by side boxplot of price comparing homes that are new and homes that are not new.

# %%
plt.figure(figsize=(8, 6))
houses.boxplot(column='price', by='new', vert=False,grid = False)
plt.title('Side-by-Side Box Plot of Price by New')
plt.xlabel('Price')
plt.ylabel('New')
plt.show()

# %% [markdown]
# Part e. What is the relationship between size and price.  Justify your answer using the plots created. Do the same for the relationship between price and whether or not a house is new, again using the plot to justify your answer.

# %% [markdown]
# Size and price have a positive linear relationship, which is seen by the scatter plot, and the regression line, showing that as price increases, so does the size of the house.
#
# There is also a positive relationship between price and newness of a house, as shown in the side by side box plots. The median price and price range of old houses are much lower than the median and price range of the new houses, showing that new houses are more expensive as a whole.

# %% [markdown]
# **Problem 1.22**. Using the Happy data file read in by the following code. Construct the contingency table relating marital status and happiness.

# %%
happy = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Happy.dat")

# %%
pd.crosstab(happy['marital'],happy['happiness'])
# Out:
# happiness    1  1     1  1     2  1     3    2  2     1  2     2  2     3  \
# marital
# fe         348        0        0        0  642        0        0        0
# fem          0        5        0        0    0        0        0        0
# mal          0      107       33       56    0      229      114      210
# male         0       99        0        0    0        0        0        0
#
# happiness    3  3     1  3     2  3     3
# marital
# fe         153        0        0        0
# fem          0        0        0        0
# mal          0       33       45       68
# male         0        0        0        0
